# %%
import pandas as pd

# %%
data_path = '../data/'

# %%
geocoder_res = pd.read_feather(data_path + 'geo/geocoder_results_final.frt')
# weather_res = pd.read_feather(data_path + 'geo/weather_results_final.frt')
ipc = pd.read_feather(data_path + 'external/ipc_preprocessed.frt')
cb_rate = pd.read_feather(data_path + 'external/cb_rate_preprocessed.frt')

# %%
ipc.head()
# Out:
#        area       date  Базовый индекс потребительских цен  \
# 0  амурская 2016-01-01                              101.07
# 1  амурская 2016-02-01                              100.81
# 2  амурская 2016-03-01                              100.57
# 3  амурская 2016-04-01                              100.38
# 4  амурская 2016-05-01                              100.40
#
#    Все товары и услуги  Жилищно-коммунальные услуги  \
# 0               100.93                       100.05
# 1               100.94                       100.00
# 2               100.48                       100.00
# 3               100.26                       100.01
# 4               100.43                        99.94
#
#    Жилищные услуги без аренды квартир у частных лиц  \
# 0                                            100.13
# 1                                            100.00
# 2                                            100.00
# 3                                            100.00
# ...
